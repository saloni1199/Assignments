# %% [markdown]
# 1) Prepare a classification model using Naive Bayes
# for salary data
#
# Data Description:
#
# age -- age of a person
# workclass	-- A work class is a grouping of work
# education	-- Education of an individuals
# maritalstatus -- Marital status of an individulas
# occupation	 -- occupation of an individuals
# relationship --
# race --  Race of an Individual
# sex --  Gender of an Individual
# capitalgain --  profit received from the sale of an investment
# capitalloss	-- A decrease in the value of a capital asset
# hoursperweek -- number of hours work per week
# native -- Native of an individual
# Salary -- salary of an individual

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix

from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB

# %%
train = pd.read_csv("SalaryData_Train.csv")
train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
test = pd.read_csv("SalaryData_Test.csv")
test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %% [markdown]
# # EDA on Train data

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
train.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
train[train.duplicated()].shape
# Out:
# (3258, 14)

# %%
train[train.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 326     33   Private      Bachelors           13   Married-civ-spouse
# 364     27   Private      Bachelors           13        Never-married
# 518     24   Private        HS-grad            9        Never-married
# 525     24   Private        HS-grad            9        Never-married
# 619     33   Private      Bachelors           13   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 30110   47   Private        HS-grad            9   Married-civ-spouse
# 30118   20   Private        HS-grad            9        Never-married
# 30132   22   Private   Some-college           10        Never-married
# 30157   40   Private        HS-grad            9   Married-civ-spouse
# 30159   22   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# 326       Exec-managerial         Husband   White     Male            0
# 364          Craft-repair   Not-in-family   White     Male            0
# 518     Handlers-cleaners       Unmarried   Black   Female            0
# 525          Craft-repair       Own-child   White     Male            0
# 619       Exec-managerial         Husband   White     Male            0
# ...                   ...             ...     ...      ...          ...
# 30110        Craft-repair         Husband   White     Male            0
# 30118   Machine-op-inspct       Own-child   White     Male            0
# 30132        Adm-clerical       Own-child   White     Male            0
# 30157   Machine-op-inspct         Husband   White     Male            0
# 30159        Adm-clerical       Own-child   White     Male            0
#
#        capitalloss  hoursperweek          native  Salary
# 326              0            40   United-States    >50K
# 364              0            50   United-States   <=50K
# 518              0            40   United-States   <=50K
# 525              0            40   United-States   <=50K
# 619              0            40   United-States    >50K
# ...            ...           ...             ...     ...
# 30110            0            40   United-States   <=50K
# 30118            0            40   United-States   <=50K
# 30132            0            40   United-States   <=50K
# 30157            0            40   United-States    >50K
# 30159            0            20   United-States   <=50K
#
# [3258 rows x 14 columns]

# %%
train1 = train.drop_duplicates()
train1.iloc[325:330]
# Out:
#      age     workclass   education  educationno        maritalstatus  \
# 325   26       Private     HS-grad            9   Married-civ-spouse
# 327   46     Local-gov        11th            7   Married-civ-spouse
# 328   38   Federal-gov     HS-grad            9   Married-civ-spouse
# 329   65       Private        11th            7              Widowed
# 330   40       Private   Assoc-voc           11   Married-civ-spouse
#
#             occupation relationship    race    sex  capitalgain  capitalloss  \
# 325      Other-service      Husband   White   Male            0            0
# 327   Transport-moving      Husband   White   Male            0            0
# 328       Adm-clerical      Husband   White   Male            0            0
# 329      Other-service    Unmarried   Other   Male            0            0
# 330       Tech-support      Husband   White   Male            0            0
#
#      hoursperweek          native  Salary
# 325            40   United-States   <=50K
# 327            30   United-States   <=50K
# 328            40   United-States    >50K
# 329            40   United-States   <=50K
# 330            40   United-States    >50K

# %%
train2 = train1.reset_index()
train2 = train2.drop(columns="index")
train2.iloc[325:330]
# Out:
#      age     workclass   education  educationno        maritalstatus  \
# 325   26       Private     HS-grad            9   Married-civ-spouse
# 326   46     Local-gov        11th            7   Married-civ-spouse
# 327   38   Federal-gov     HS-grad            9   Married-civ-spouse
# 328   65       Private        11th            7              Widowed
# 329   40       Private   Assoc-voc           11   Married-civ-spouse
#
#             occupation relationship    race    sex  capitalgain  capitalloss  \
# 325      Other-service      Husband   White   Male            0            0
# 326   Transport-moving      Husband   White   Male            0            0
# 327       Adm-clerical      Husband   White   Male            0            0
# 328      Other-service    Unmarried   Other   Male            0            0
# 329       Tech-support      Husband   White   Male            0            0
#
#      hoursperweek          native  Salary
# 325            40   United-States   <=50K
# 326            30   United-States   <=50K
# 327            40   United-States    >50K
# 328            40   United-States   <=50K
# 329            40   United-States    >50K

# %%
labelencoder = LabelEncoder()
names = train2[["workclass", "education", "maritalstatus", "occupation", "relationship", "race", "sex", "native", "Salary"]]

# %%
for i in names:
    train2[i] = labelencoder.fit_transform(train2[i])
    
train2.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4
#
#    Salary
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # EDA on Test data

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
test.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
test[test.duplicated()].shape
# Out:
# (930, 14)

# %%
test[test.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 551     59   Private        HS-grad            9             Divorced
# 601     32   Private        HS-grad            9   Married-civ-spouse
# 681     40   Private        HS-grad            9   Married-civ-spouse
# 799     24   Private      Bachelors           13        Never-married
# 1044    44   Private    Prof-school           15   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15043   51   Private        HS-grad            9   Married-civ-spouse
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# 551         Other-service   Not-in-family   White   Female            0
# 601                 Sales         Husband   White     Male            0
# 681          Craft-repair         Husband   White     Male            0
# 799        Prof-specialty   Not-in-family   White     Male            0
# 1044       Prof-specialty         Husband   White     Male        99999
# ...                   ...             ...     ...      ...          ...
# 15043        Craft-repair         Husband   White     Male            0
# 15044        Craft-repair       Own-child   White     Male            0
# 15049   Handlers-cleaners         Husband   White     Male            0
# 15052        Craft-repair         Husband   White     Male            0
# 15053       Other-service       Own-child   White   Female            0
#
#        capitalloss  hoursperweek          native  Salary
# 551              0            40   United-States   <=50K
# 601              0            40   United-States   <=50K
# 681              0            40   United-States   <=50K
# 799              0            35   United-States   <=50K
# 1044             0            60   United-States    >50K
# ...            ...           ...             ...     ...
# 15043            0            40   United-States   <=50K
# 15044            0            40   United-States   <=50K
# 15049            0            40   United-States   <=50K
# 15052            0            40   United-States   <=50K
# 15053            0            40   United-States   <=50K
#
# [930 rows x 14 columns]

# %%
test1 = test.drop_duplicates()
test1.iloc[550:555]
# Out:
#      age      workclass      education  educationno        maritalstatus  \
# 550   49        Private      Bachelors           13   Married-civ-spouse
# 552   38        Private        HS-grad            9            Separated
# 553   50   Self-emp-inc   Some-college           10   Married-civ-spouse
# 554   51   Self-emp-inc   Some-college           10   Married-civ-spouse
# 555   22        Private   Some-college           10        Never-married
#
#              occupation relationship                 race      sex  \
# 550     Exec-managerial      Husband                White     Male
# 552   Machine-op-inspct    Unmarried                Black   Female
# 553               Sales      Husband                White     Male
# 554        Craft-repair      Husband                White     Male
# 555   Machine-op-inspct    Own-child   Asian-Pac-Islander     Male
#
#      capitalgain  capitalloss  hoursperweek          native  Salary
# 550            0            0            50   United-States    >50K
# 552            0            0            28   United-States   <=50K
# 553            0            0            55   United-States   <=50K
# 554            0         1672            55   United-States   <=50K
# 555            0            0            35   United-States   <=50K

# %%
test2 = test1.reset_index()
test2 = test2.drop(columns="index")
test2.iloc[550:555]
# Out:
#      age      workclass      education  educationno        maritalstatus  \
# 550   49        Private      Bachelors           13   Married-civ-spouse
# 551   38        Private        HS-grad            9            Separated
# 552   50   Self-emp-inc   Some-college           10   Married-civ-spouse
# 553   51   Self-emp-inc   Some-college           10   Married-civ-spouse
# 554   22        Private   Some-college           10        Never-married
#
#              occupation relationship                 race      sex  \
# 550     Exec-managerial      Husband                White     Male
# 551   Machine-op-inspct    Unmarried                Black   Female
# 552               Sales      Husband                White     Male
# 553        Craft-repair      Husband                White     Male
# 554   Machine-op-inspct    Own-child   Asian-Pac-Islander     Male
#
#      capitalgain  capitalloss  hoursperweek          native  Salary
# 550            0            0            50   United-States    >50K
# 551            0            0            28   United-States   <=50K
# 552            0            0            55   United-States   <=50K
# 553            0         1672            55   United-States   <=50K
# 554            0            0            35   United-States   <=50K

# %%
labelencoder = LabelEncoder()
names = test2[["workclass", "education", "maritalstatus", "occupation", "relationship", "race", "sex", "native", "Salary"]]

# %%
for i in names:
    test2[i] = labelencoder.fit_transform(test2[i])
    
test2.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          2          1            7              4           6
# 1   38          2         11            9              2           4
# 2   28          1          7           12              2          10
# 3   44          2         15           10              2           6
# 4   34          2          0            6              4           7
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             3     2    1            0            0            40      37
# 1             0     4    1            0            0            50      37
# 2             0     4    1            0            0            40      37
# 3             0     2    1         7688            0            40      37
# 4             1     4    1            0            0            30      37
#
#    Salary
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0

# %% [markdown]
# # Train & Test Split

# %%
x_train = train2.iloc[:, 0:13]
y_train = train2.iloc[:, 13]
x_test = test2.iloc[:, 0:13]
y_test = test2.iloc[:, 13]

# %% [markdown]
# # Normalization

# %%
def norm_func (i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
x_train = norm_func(x_train)
x_test =  norm_func(x_test)

# %% [markdown]
# # Building model using Gaussian Naive Bayes

# %%
gb = GaussianNB()
gb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
pred_gb = gb.predict(x_test)
pred_gb
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
confusion_matrix(y_test, pred_gb)
# Out:
# array([[10030,   590],
#        [ 2296,  1214]], dtype=int64)

# %%
accuracy = accuracy_score(y_test, pred_gb)
print((accuracy)*100)
# Out:
# 79.57537154989384

# %%
print("The accuracy of the Gaussian Naive Bayes classifier on training data is {:.2f} out of 1".format(gb.score(x_train, y_train)*100))

print("The accuracy of the Gaussian Naive Bayes classifier on test data is {:.2f} out of 1".format(gb.score(x_test, y_test)*100))
# Out:
# The accuracy of the Gaussian Naive Bayes classifier on training data is 79.56 out of 1
# The accuracy of the Gaussian Naive Bayes classifier on test data is 79.58 out of 1

# %% [markdown]
# # Building model using Multinomial Naive Bayes

# %%
mb = MultinomialNB()
mb.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
pred_mb = mb.predict(x_test)
pred_mb
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
confusion_matrix(y_test, pred_mb)
# Out:
# array([[10616,     4],
#        [ 3425,    85]], dtype=int64)

# %%
accuracy = accuracy_score(y_test, pred_mb)
print((accuracy)*100)
# Out:
# 75.73248407643312

# %%
print("The accuracy of the Multinomial Naive Bayes classifier on training data is {:.2f} out of 1".format(mb.score(x_train, y_train)*100))

print("The accuracy of the Multinomial Naive Bayes classifier on test data is {:.2f} out of 1".format(mb.score(x_test, y_test)*100))
# Out:
# The accuracy of the Multinomial Naive Bayes classifier on training data is 74.99 out of 1
# The accuracy of the Multinomial Naive Bayes classifier on test data is 75.73 out of 1

# %% [markdown]
# # Conclusion

# %% [markdown]
# GaussianNB Model has a better Accuracy, Thus we will use GaussianNB Classifier on Salary data.
